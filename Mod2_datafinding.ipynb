# %% [markdown]
# <a href="https://colab.research.google.com/github/nevchia5/nev-teach-nev/blob/main/Mod2_datafinding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook for Module 2 Team4 Project
# Neville for Team4 **bold text**

# %% [markdown]
# Objective:
# Build an end-to-end data pipeline and analysis workflow for company A.

# %% [markdown]
# 1. Raw data files, preferrably public

# %% [markdown]
# 2. Load to data warehouse

# %% [markdown]
# 3. ELT the data.

# %% [markdown]
# 4. Ensure data quality

# %% [markdown]
# 5. Analyse the data

# %% [markdown]
# Presentation to include:

# %% [markdown]
# 1. Project solution

# %% [markdown]
# 2. Key findings and data-driven business recommendations

# %% [markdown]
# keywords: *compelling business narrative*

# %% [markdown]
# Compelling Ideas:
# 1. [link textStation Crowd Density Real Time](https://datamall.lta.gov.sg/content/datamall/en/dynamic-data.html)(dynamic dataset)
# Business case for a convenience store chain looking to invest in outlets around MRT stations: no go. data stopped since 2024.

# %% [markdown]
# 2. [Electric Vehicle Population Data 2025](https://www.kaggle.com/datasets/yanghu583/electric-vehicle-population-data-2025/discussion?sort=hotness)
# (~60MB CSV dataset)
# Business case presentation for an energy company looking for locations to invest in EV charging stations and potential collaboration  with a convenience store chain.

# %% [markdown]
# 3. [Public bike use data 2014-2024 (MiBici)](https://www.kaggle.com/datasets/sebastianquirarte/over-9-years-of-real-public-bike-use-data-mibici) (cleaned data)
# Business case suggestion for e-bike company to deploy bike charging stations with vending machines.

# %% [markdown]
# 4. [Thailand public train data (Bangkok area)](https://www.kaggle.com/datasets/gusbell/thailand-public-train-data-bangkok-area/data) (CSV file converted from JSON)
# Business case suggestion for convenience store chain to build stores in the right locations.

# %% [markdown]
# 5. [New York City Airbnb Open Data](https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data/code)
# Business case suggestion for a property investment company. Insights guide their investment strategy.

# %% [markdown]
# 6. *from Daniel [Netflix Movies and TV Shows](https://www.kaggle.com/datasets/shivamb/netflix-shows)
# Business case for Netflix to promote advertising space and purchase of new genres/titles for members.
